# %% [markdown]
# <a href="https://colab.research.google.com/github/Blusooyeon/Studying_for_Bigdata_Test/blob/main/T1_22_time_series4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 주어진 데이터(basic2.csv)에서 주 단위 Sales의 합계를 구하고, 가장 큰 값을 가진 주와 작은 값을 가진 주의 차이를 구하시오(절대값)

# %%
import pandas as pd

df = pd.read_csv('/content/basic2.csv', parse_dates=['Date'], index_col=0)

# %%
print(df.shape)
df.head()
# Out:
# (730, 4)
#                Sales      PV      UV  Events
# Date
# 2022-01-01  22711525  397349  4421.0       1
# 2022-01-02     36779    3969  2289.0       0
# 2022-01-03  13943875  373890     NaN       1
# 2022-01-04   8088593  142054  2157.0       0
# 2022-01-05   2395374  190684     NaN       0

# %%
# 주 단위로 나누기
df_w = df.resample('W').sum()
df_w.head()
# Out:
#                Sales       PV       UV  Events
# Date
# 2022-01-02  22748304   401318   6710.0       1
# 2022-01-09  33373822  1148464  15189.0       2
# 2022-01-16  20754519   283773   9344.0       0
# 2022-01-23  21880751   538633   9841.0       1
# 2022-01-30  28878452   560814   7808.0       1

# %%
# 결과 출력
print(df_w['Sales'].max() - df_w['Sales'].min())
# Out:
# 91639050

# %% [markdown]
# ✅check
# 1. 주 단위로 나누기
# df.resample('W').sum()

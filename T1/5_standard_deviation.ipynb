# %% [markdown]
# <a href="https://colab.research.google.com/github/Blusooyeon/Studying_for_Bigdata_Test/blob/main/T1_5_standard_deviation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 조건에 맞는 데이터 표준편차 구하기
# 주어진 데이터 중 'f4' 컬럼 값이 'ENFJ'와 'INFP' 인 'f1'의 표준편차 차이를 절대값으로 구하시오

# %%
# 라이브러리 및 데이터 불러오기
import pandas as pd
import numpy as np

df = pd.read_csv('/content/basic1.csv')
df.head()
# Out:
#      id   age city    f1  f2   f3    f4         f5
# 0  id01   2.0   서울   NaN   0  NaN  ENFJ  91.297791
# 1  id02   9.0   서울  70.0   1  NaN  ENFJ  60.339826
# 2  id03  27.0   서울  61.0   1  NaN  ISTJ  17.252986
# 3  id04  75.0   서울   NaN   2  NaN  INFP  52.667078
# 4  id05  24.0   서울  85.0   2  NaN  ISFJ  29.269869

# %%
# 조건에 맞는 데이터 찾기
df[df['f4']=='ENFJ']
# Out:
#       id   age city    f1  f2   f3    f4         f5
# 0   id01   2.0   서울   NaN   0  NaN  ENFJ  91.297791
# 1   id02   9.0   서울  70.0   1  NaN  ENFJ  60.339826
# 32  id33  47.0   부산  94.0   0  NaN  ENFJ  17.252986
# 40  id41  81.0   대구  55.0   0  NaN  ENFJ  37.113739
# 44  id45  97.0   대구  88.0   0  NaN  ENFJ  13.049921
# 53  id54  53.0   대구   NaN   1  NaN  ENFJ  69.730313

# %%
# 조건에 맞는 f1의 표준편자 구하기
enfj = df[df['f4']=='ENFJ']['f1'].std()

infp = df[df['f4']=='INFP']['f1'].std()

# %%
# 두 표준편차 차이 절댓값 출력
print(np.abs(enfj-infp))
# Out:
# 5.859621525876811

# %% [markdown]
# ✅ Check
# 1. 표준편차 구하기
# 데이터.std()
# 2. 절댓값 출력하기
# np.abs(숫자)
